# %% [markdown]
# <a href="https://colab.research.google.com/github/nepslor/teaching/blob/main/CAS_BDML/L1_bounty_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('https://github.com/nepslor/teaching/raw/refs/heads/main/CAS_BDML/bounty_data.csv')

# %%
df
# Out:
#                               x          y
# 2024-01-01 00:00:00         NaN        NaN
# 2024-01-01 01:00:00         NaN        NaN
# 2024-01-01 02:00:00 -392.967265 -48.656775
# 2024-01-01 03:00:00         NaN        NaN
# 2024-01-01 04:00:00 -391.978051 -50.028542
# ...                         ...        ...
# 2027-07-19 05:00:00 -408.110875 -60.083309
# 2027-07-19 06:00:00 -402.353592 -55.229353
# 2027-07-19 07:00:00         NaN        NaN
# 2027-07-19 08:00:00         NaN        NaN
# 2027-07-19 09:00:00 -401.294357 -50.613007
#
# [31090 rows x 2 columns]
